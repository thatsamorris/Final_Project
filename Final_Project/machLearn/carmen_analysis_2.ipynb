# %%
 # %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
census = pd.read_csv('data/crime and census/combined_cleaned_encode.csv')
census.head(500)
# Out:
#      zipcode  total_crimes  Population  Median Age  Household Income  \
# 0    85746.0       29633.0     42704.0        31.8           41427.0
# 1    85706.0       38102.0     56989.0        27.5           29814.0
# 2    85756.0        8557.0     35522.0        31.8           46672.0
# 3    85747.0        4670.0     23490.0        34.5           81474.0
# 4    85748.0        2971.0     18275.0        45.4           69871.0
# 5    85321.0         433.0      4727.0        45.2           28053.0
# 6    85634.0         546.0      5982.0        29.4           27854.0
# 7    65555.0          79.0      1077.0        52.1           38125.0
# 8    85741.0        1913.0     35191.0        34.7           51871.0
# 9    85745.0        1853.0     37654.0        36.8           49380.0
# 10   73755.0          24.0       719.0        45.0           36364.0
# 11   85640.0          16.0       487.0        62.1           23500.0
# 12   85757.0         565.0     18341.0        29.5           51220.0
# ...

# %%
census['Household Income'].dtype
# Out:
# dtype('float64')

# %%
# result2 = census.dropna()
result2.shape
# result2.to_csv('combined_cleaned_encode.csv', encoding='utf-8', index=False)
# Out:
# (440, 11)

# %%
np.isnan(openingPriceTrain).any()
# Out:
# ['zipcode', 'total_crimes', 'Population', 'Median Age', 'Household Income', 'Per Capita Income', 'Poverty Count', 'Poverty Rate', 'crime rate', 'crime rating', 'crime encode']

# %%
array = ["Population", "Median Age", "Per Capita Income", "Poverty Count", "Poverty Rate", "Household Income"]

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

for variable in array:
    X = result2[variable].values.reshape(-1, 1)
    y = result2["crime rate"].values.reshape(-1, 1)

    # Fitting our model with all of our features in X
    model.fit(X, y)

    score = model.score(X, y)
    print(f"{variable} - R2 Score: {score}")
# Out:
# Population - R2 Score: 0.0491721904879906
# Median Age - R2 Score: 0.03262041333956789
# Per Capita Income - R2 Score: 0.008618314184218656
# Poverty Count - R2 Score: 0.1422909352974573
# Poverty Rate - R2 Score: 0.0763280719134799
# Household Income - R2 Score: 0.0343054393107185

# %%
X = result2[["Median Age", "Household Income", "Per Capita Income", "Poverty Rate"]]
y = result2["crime rate"].values.reshape(-1, 1)

# Fitting our model with all of our features in X
model.fit(X, y)

score = model.score(X, y)
print(f"R2 Score: {score}")
# Out:
# R2 Score: 0.10641696341975126

# %%
#splitting into train and test data
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)
#retraining model with train data
model.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
print(f"Training Data Score: {model.score(X_train, y_train)}")
print(f"Testing Data Score: {model.score(X_test, y_test)}")
# Out:
# Training Data Score: 0.11404207951854384
# Testing Data Score: 0.08209023293272288
